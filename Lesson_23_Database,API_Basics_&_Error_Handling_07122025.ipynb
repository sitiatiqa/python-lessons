# %%
# Databe & API Basics

# %%
import time
print(1)
time.sleep(3)
print(2)
# Out:
# 1
# 2

# %% [markdown]
# <img src="https://media.licdn.com/dms/image/C4D12AQEFVtNMImgI0Q/article-cover_image-shrink_600_2000/0/1618364613028?e=2147483647&v=beta&t=t8ZlVOgL3Prc8IkJF8UfmWlUbh0pB9qfMs-c6zHGHhk" width="600px">
#
# <img src="https://buildfire.com/wp-content/uploads/2023/03/Requests.png" width="600px">
#
# - **Synchronous code** will block further execution of the remaining code until it finishes the current one.
# - **Asynchronous code** allows the program to be executed immediately

# %%
#Fetching data from Database

# %% [markdown]
# <img src="https://i.ibb.co/YNJ7cPF/Whats-App-Image-2024-07-22-at-13-10-10.jpg" alt="Whats-App-Image-2024-07-22-at-13-10-10" border="0" width="450">

# %%
import requests
response = requests.get('https://jsonplaceholder.typicode.com/todos')
print(response)
print('-------------')
posts = response.json()
print(posts)
print('-----')
print(len(posts))
# Out:
# <Response [200]>
# -------------
# ...

# %%
for x in posts:
  print(x)
  print('-' * 100)
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}
# ----------------------------------------------------------------------------------------------------
# {'userId': 1, 'id': 2, 'title': 'quis ut nam facilis et officia qui', 'completed': False}
# ----------------------------------------------------------------------------------------------------
# {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False}
# ----------------------------------------------------------------------------------------------------
# {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True}
# ----------------------------------------------------------------------------------------------------
# {'userId': 1, 'id': 5, 'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum', 'completed': False}
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# #2 Error Handling

# %%
x = 'hello' + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1927242002.py in <cell line: 0>()
# ----> 1 x = 'hello' + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
try:
  x = 'Hello' + 5
  print(x)
except TypeError:
  print('cant concat int + str')
# Out:
# cant concat int + str

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:4800/format:webp/1*vcdP5S7yT7-AK9CZM5_70g.png" width="600px">

# %%
try:
  x = 'Hello' + [1,5,8]
  print(x)
except TypeError as e:
  print(e)
# Out:
# can only concatenate str (not "list") to str

# %%
list1 = [213,321,432,1234]
try:
  print(list1[4])
except TypeError:
  print('can not run')
except IndexError:
  print('no such index')
# Out:
# no such index

# %% [markdown]
# Ask the user for a number. If they enter
#
# something that’s not a number, show an error message.
#
#
# Add a number and a string to trigger TypeError.
#
# User enters 2 numbers.
#
# Catches both errors differently.
#
# Show that the finally block always runs.

# %%
try:
  num1_str = input("Enter the first number: ")
  num1 = int(num1_str)
  num2_str = input("Enter the second number: ")
  num2 = int(num2_str)
except ValueError:
    print("Not a valid age!")
# Out:
# Enter the first number: k
# Not a valid age!
