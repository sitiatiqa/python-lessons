# %%
#pivot table

# %% [markdown]
# <img src="https://i.ibb.co/dGp3wWS/pivot.png" alt="pivot" border="0"></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Sales_Funnel_CRM.csv")

# %%
df
# Out:
#     Account Number       Company       Contact Account Manager  \
# 0          2123398        Google   Larry Pager    Edward Thorp
# 1          2123398        Google   Larry Pager    Edward Thorp
# 2          2123398        Google   Larry Pager    Edward Thorp
# 3          2192650          BOBO   Larry Pager    Edward Thorp
# 4           420496          IKEA     Elon Tusk    Edward Thorp
# 5           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 6           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 7          1216870     Microsoft   Will Grates    Edward Thorp
# 8          2200450       Walmart   Will Grates    Edward Thorp
# 9           405886         Apple  Cindy Phoner  Claude Shannon
# 10          470248  Exxon Mobile  Cindy Phoner  Claude Shannon
# 11          698032           ATT  Cindy Phoner  Claude Shannon
# 12          698032           ATT  Cindy Phoner  Claude Shannon
# 13          902797    CVS Health  Emma Gordian  Claude Shannon
# ...

# %%
pd.pivot(data=df, index= 'Company', columns = 'Product', values= 'Licenses')
# Out:
# Product       Analytics  GPS Positioning  Prediction  Tracking
# Company
#  Google           150.0              NaN       150.0     300.0
# ATT                 NaN              NaN       150.0     150.0
# Apple             300.0              NaN         NaN       NaN
# BOBO              150.0              NaN         NaN       NaN
# CVS Health          NaN              NaN         NaN     450.0
# Cisco             300.0            300.0         NaN       NaN
# Exxon Mobile      150.0              NaN         NaN       NaN
# IKEA              300.0              NaN         NaN       NaN
# Microsoft           NaN              NaN         NaN     300.0
# Salesforce        750.0              NaN         NaN       NaN
# Tesla Inc.        300.0              NaN       150.0       NaN
# Walmart           150.0              NaN         NaN       NaN

# %%
df[['Company','Product']]
# Out:
#          Company          Product
# 0         Google        Analytics
# 1         Google       Prediction
# 2         Google         Tracking
# 3           BOBO        Analytics
# 4           IKEA        Analytics
# 5     Tesla Inc.        Analytics
# 6     Tesla Inc.       Prediction
# 7      Microsoft         Tracking
# 8        Walmart        Analytics
# 9          Apple        Analytics
# 10  Exxon Mobile        Analytics
# 11           ATT         Tracking
# 12           ATT       Prediction
# 13    CVS Health         Tracking
# 14    Salesforce        Analytics
# 15         Cisco        Analytics
# 16         Cisco  GPS Positioning

# %%
pd.pivot(data= df, index = 'Account Manager', columns='Product', values= 'Licenses')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-241433151.py in <cell line: 0>()
# ----> 1 pd.pivot(data= df, index = 'Account Manager', columns='Product', values= 'Licenses')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/pivot.py in pivot(data, columns, index, values)
#     568     # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     569     # "Hashable"
# --> 570     result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     571     result.index.names = [
#     572         name if name is not lib.no_default else None for name in result.index.names
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in unstack(self, level, fill_value, sort)
#    4613         from pandas.core.reshape.reshape import unstack
#    4614
# -> 4615         return unstack(self, level, fill_value, sort)
# ...

# %%
df[['Account Manager','Product']]
# Out:
#    Account Manager          Product
# 0     Edward Thorp        Analytics
# 1     Edward Thorp       Prediction
# 2     Edward Thorp         Tracking
# 3     Edward Thorp        Analytics
# 4     Edward Thorp        Analytics
# 5     Edward Thorp        Analytics
# 6     Edward Thorp       Prediction
# 7     Edward Thorp         Tracking
# 8     Edward Thorp        Analytics
# 9   Claude Shannon        Analytics
# 10  Claude Shannon        Analytics
# 11  Claude Shannon         Tracking
# 12  Claude Shannon       Prediction
# 13  Claude Shannon         Tracking
# 14  Claude Shannon        Analytics
# 15  Claude Shannon        Analytics
# 16  Claude Shannon  GPS Positioning

# %% [markdown]
# ### Example:
# <img src="https://i.ibb.co/7thSc4p/pivot-table.png" alt="pivot-table" border="0">

# %%
pd.pivot_table(data = df, index="Account Manager", columns="Product", values="Sale Price")
# Out:
# Product          Analytics  GPS Positioning  Prediction  Tracking
# Account Manager
# Claude Shannon   4550000.0         350000.0    700000.0  420000.0
# Edward Thorp     2870000.0              NaN    700000.0  350000.0

# %%
pd.pivot_table(df,index=["Account Manager","Contact"],values=['Sale Price'],aggfunc='sum')
# Out:
#                               Sale Price
# Account Manager Contact
# Claude Shannon  Cindy Phoner     7700000
#                 Emma Gordian    12390000
# Edward Thorp    Elon Tusk        8050000
#                 Larry Pager      5600000
#                 Will Grates      2800000

# %%
pd.pivot_table(df,index=["Account Manager","Contact"],values=["Sale Price"],columns=["Product"],
               aggfunc=[np.sum,np.mean],fill_value=0)
# Out:
# /tmp/ipython-input-3665346100.py:1: FutureWarning: The provided callable <function sum at 0x7af6f6b9e7a0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df,index=["Account Manager","Contact"],values=["Sale Price"],columns=["Product"],
# /tmp/ipython-input-3665346100.py:1: FutureWarning: The provided callable <function mean at 0x7af6f6b9f880> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(df,index=["Account Manager","Contact"],values=["Sale Price"],columns=["Product"],
#                                     sum                                      \
#                              Sale Price
# Product                       Analytics GPS Positioning Prediction Tracking
# Account Manager Contact
# ...
