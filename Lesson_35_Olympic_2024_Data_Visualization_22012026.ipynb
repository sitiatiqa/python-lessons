# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
athletes_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/athletes (2).csv')

# %%
athletes_data.head()
# Out:
#       code  current               name     name_short            name_tv  \
# 0  1532872     True   ALEKSANYAN Artur   ALEKSANYAN A   Artur ALEKSANYAN
# 1  1532873     True     AMOYAN Malkhas       AMOYAN M     Malkhas AMOYAN
# 2  1532874     True    GALSTYAN Slavik     GALSTYAN S    Slavik GALSTYAN
# 3  1532944     True  HARUTYUNYAN Arsen  HARUTYUNYAN A  Arsen HARUTYUNYAN
# 4  1532945     True    TEVANYAN Vazgen     TEVANYAN V    Vazgen TEVANYAN
#
#   gender function country_code  country country_long  ...  \
# 0   Male  Athlete          ARM  Armenia      Armenia  ...
# 1   Male  Athlete          ARM  Armenia      Armenia  ...
# 2   Male  Athlete          ARM  Armenia      Armenia  ...
# 3   Male  Athlete          ARM  Armenia      Armenia  ...
# 4   Male  Athlete          ARM  Armenia      Armenia  ...
#
#                                               family  \
# 0                          Father, Gevorg Aleksanyan
# 1                                                NaN
# ...

# %%
# No of Male and Female Athletes

# %%
print(athletes_data['gender'].value_counts())
# Out:
# gender
# Male      5658
# Female    5455
# Name: count, dtype: int64

# %%
sns.countplot(athletes_data, x = athletes_data['gender'])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
# Top Countries with highest number of athletes

# %%
top = athletes_data['country'].value_counts().head(10).index
print(top)

top_10 = athletes_data[athletes_data['country'].isin(top)]
# Out:
# Index(['United States', 'France', 'Australia', 'Germany', 'Japan', 'Spain',
#        'China', 'Italy', 'Great Britain', 'Canada'],
#       dtype='object', name='country')

# %%
plt.figure(figsize=(25,15))
sns.countplot(data = top_10, x = 'country', hue = 'gender')
# Out:
# <Axes: xlabel='country', ylabel='count'>

# %%
# Top Countries with highest no of male athletes
male = athletes_data[athletes_data['gender'] == 'Male']
top_male = male['country'].value_counts().head(5).index
top_male_countries = male[athletes_data['country'].isin(top_male)]


# female = athletes_data[athletes_data['gender'] == 'Female']
# Out:
# /tmp/ipython-input-3963437916.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   top_male_countries = male[athletes_data['country'].isin(top_male)]

# %%
sns.countplot(top_male_countries, x = 'country')
# Out:
# <Axes: xlabel='country', ylabel='count'>

# %%
top_games = athletes_data['disciplines'].value_counts().head(8).index
top_8_games = athletes_data[athletes_data['disciplines'].isin(top_games)]

# %%
sns.countplot(top_8_games, x = 'disciplines')
plt.xticks(rotation = 45, fontsize = 12)
plt.show()

# %%
bot_games = athletes_data['disciplines'].value_counts().tail(8).index
bot_8_games = athletes_data[athletes_data['disciplines'].isin(bot_games)]

# %%
sns.countplot(bot_8_games, y = 'disciplines')
plt.show()
