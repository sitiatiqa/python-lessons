# %%
import numpy as np
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/movie_scores.csv")
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
# .isnull()
df.isnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0       False      False  False  False            False             False
# 1        True       True   True   True             True              True
# 2       False      False  False  False             True              True
# 3       False      False  False  False            False             False
# 4       False      False  False  False            False             False

# %%
df.isnull().sum()  #show empty cells in column first
# Out:
# first_name          1
# last_name           1
# age                 1
# sex                 1
# pre_movie_score     2
# post_movie_score    2
# dtype: int64

# %%
# notnull()
df.notnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0        True       True   True   True             True              True
# 1       False      False  False  False            False             False
# 2        True       True   True   True            False             False
# 3        True       True   True   True             True              True
# 4        True       True   True   True             True              True

# %%
df.notnull().sum()
# Out:
# first_name          4
# last_name           4
# age                 4
# sex                 4
# pre_movie_score     3
# post_movie_score    3
# dtype: int64

# %%
df.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df['first_name'].notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: first_name, dtype: bool

# %%
df[df['first_name'].notnull()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df[(df['pre_movie_score'].notnull()) | (df['post_movie_score'].notnull())]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
# i want to get all the rows where "pre_movie_score" is empty but "sex" is not empty

df[(df['pre_movie_score'].isnull()) & (df['sex'].notnull())]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 2       Hugh   Jackman  51.0   m              NaN               NaN

# %% [markdown]
# Count of Non-Null Cells

# %%
df.count()
# Out:
# first_name          4
# last_name           4
# age                 4
# sex                 4
# pre_movie_score     3
# post_movie_score    3
# dtype: int64

# %%
df.count(axis = 1)
# Out:
# 0    6
# 1    0
# 2    4
# 3    6
# 4    6
# dtype: int64

# %%
# any()
df.any()
# Out:
# first_name          True
# last_name           True
# age                 True
# sex                 True
# pre_movie_score     True
# post_movie_score    True
# dtype: bool

# %%
# example
print(bool('')) # for empty string, the result for boolean is False
# Out:
# False

# %%
# same as zero integer
print(bool(0))
# Out:
# False

# %%
list1 = [False,False,False]
print(any(list1))
# Out:
# False

# %%
list2 = [True,False,False]
print(any(list2))
# Out:
# True

# %%
list3 = [False, 0,'',0.0,{},[]]
print(any(list3))
# Out:
# False

# %%
list1 = [["hello",None,123],["Johan",32.65,{1}],[None,True,"Garry"],[[1,2,3],False,None]]
# None --> to represent empty value in Python
# typecast list --> dataframex
df = pd.DataFrame(list1, columns = ["A","B","C"])
df
# Out:
#            A      B      C
# 0      hello   None    123
# 1      Johan  32.65    {1}
# 2       None   True  Garry
# 3  [1, 2, 3]  False   None

# %%
df.isnull().any()
# Out:
# A    True
# B    True
# C    True
# dtype: bool

# %%
df.isnull().any(axis = 1)
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
df.isnull().any(axis = 1).sum()
# Out:
# np.int64(3)

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/movie_scores.csv")
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df.dropna() # remove any rows that contains at least one empty (NaN) values
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df.dropna(axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.dropna(thresh = 1) # keep any rows that has at least one empty (NaN) value
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df.dropna(thresh = 5)
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
# fill data
df.fillna("New Value")
# Out:
#   first_name  last_name        age        sex pre_movie_score post_movie_score
# 0        Tom      Hanks       63.0          m             8.0             10.0
# 1  New Value  New Value  New Value  New Value       New Value        New Value
# 2       Hugh    Jackman       51.0          m       New Value        New Value
# 3      Oprah    Winfrey       66.0          f             6.0              8.0
# 4       Emma      Stone       31.0          f             7.0              9.0

# %%
df['first_name'].fillna("Empty")
# Out:
# 0      Tom
# 1    Empty
# 2     Hugh
# 3    Oprah
# 4     Emma
# Name: first_name, dtype: object

# %%
df['first_name'] = df['first_name'].fillna("Empty")
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1      Empty       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df['pre_movie_score'].mean()
# Out:
# np.float64(7.0)

# %%
df['pre_movie_score'].fillna(df['pre_movie_score'].mean())
# Out:
# 0    8.0
# 1    7.0
# 2    7.0
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %%
df['pre_movie_score'] = df['pre_movie_score'].fillna(df['pre_movie_score'].mean())
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1      Empty       NaN   NaN  NaN              7.0               NaN
# 2       Hugh   Jackman  51.0    m              7.0               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0
