# %%
#Data Types
#Integers - Numbers without decimals
#String - Text variable = "text",'text'
#Float -Numbers with decimals
#List
#Tuples
#Sets
#Dictionary
#Boolean-True and False
#Logics
#If-Else Statement
#For Loops
#Functions

# %% [markdown]
# # String Duplication

# %%
num1 = 5
num2 = 7

print(num1 * num2)

# in python numbers, the "*" is to do multiplication
# Out:
# 35

# %%
str1 ="Jun"

print(str1 * 4)
# in python strings, the "*" is to do duplication
# Out:
# JunJunJunJun

# %%
num3 = "4"
num4 = "5"

print(num3+num4)
# Out:
# 45

# %%
text1 = "The box isn't"

# %%
text2 = """My name is Alvin
i am 25 years old
i am staying in Penang"""

# %%
text3 = '''My name is Alvin
i am 25 years old
i am staying in Penang'''

# %% [markdown]
# # String Commands / Functions

# %%
str1 = "CoDeRaNgErS"
